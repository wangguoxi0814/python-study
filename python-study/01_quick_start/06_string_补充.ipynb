# %% [markdown]
# # String

# %% [markdown]
# ## replace
# - 替换字符串，不改变原字符串,返回更换后的字符串

# %%
s1 = 'Hello World$$'
print(s1.replace('$', '*'))
print(s1)
# Out:
# Hello World**
# Hello World$$

# %% [markdown]
# ## split
# - 按指定字符分割字符串，返回列表

# %%
s2 = 'Hello*Python*World'
print(s2.split('*'))
print(s2)
# Out:
# ['Hello', 'Python', 'World']
# Hello*Python*World

# %% [markdown]
# ## format
# - 按位置参数格式化
# - 按关键字参数格式化
# - 不会改变原字符串

# %%
s3 = 'Hello {0} {1}'.format('Python', 'World')
print(s3)

s4 = '你好, {content}, {say}'.format(content='祖国', say='欢迎光临')
print(s4)

s5 = "Hello, Welcome to {country}"
s5.format(country='China')
# s5本身不发生改变
print(s5)
# Out:
# Hello Python World
# 你好, 祖国, 欢迎光临
# Hello, Welcome to {country}
